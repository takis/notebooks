# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
temp = [19, 25, 33, 30, 25, 22, 19, 13, 10, 15, 10, 10, 10, 40, 39, 38, 40, 41,40]
temp2 = range(len(temp))
plot(temp)
plot(temp2)
grid(True)
